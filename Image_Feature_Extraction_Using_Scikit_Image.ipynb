# %% [markdown]
# <a href="https://colab.research.google.com/github/ArastuDixit/Scraping-LinkedIn-using-selenium/blob/main/Image_Feature_Extraction_Using_Scikit_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow
from google.colab import drive
from PIL import Image

# %%
image1=imread('/content/drive/MyDrive/Datasets/university_capmus.jpg')

# %%
imshow(image1);

# %%
image2=imread('/content/drive/MyDrive/Datasets/university_capmus.jpg',as_gray=True)
imshow(image2);

# %%
print(image1.shape)
print(image2.shape)
# Out:
# (415, 800, 3)
# (415, 800)

# %%
print(image1.size)
print(image2.size)
# Out:
# 996000
# 332000

# %%
pixel_feat1 = np.reshape(image2, (415 * 800))
pixel_feat1
# Out:
# array([0.25490196, 0.25490196, 0.25490196, ..., 0.59627098, 0.58842784,
#        0.54529059])

# %%
pixel_feat2 = np.reshape(image1, (415 * 800 * 3))
pixel_feat2
# Out:
# array([ 65,  65,  65, ..., 148, 137, 133], dtype=uint8)

# %%
from skimage import filters

# %%
prewitth = np.array([[ -1, -1, -1],
                     [ 0, 0, 0],
                     [ 1, 1, 1]])

# %%
prewittv = np.array([[-1, 0, 1],
                     [-1,0,1],
                     [-1, 0, 1]])

# %%
plt.imshow(image2, cmap='gray')

# %%
from skimage import data
from skimage import filters
from skimage.filters import gaussian

# %%
edges = filters.prewitt(image2)

# %%
edges = filters.prewitt_h(image2)

# %%
edges = filters.prewitt_v(image2)

# %%
edges = filters.sobel(image2)

# %%
filteredimg = gaussian(image2)

# %%
from skimage.filters.edges import prewitt_h
from skimage.filters.edges import prewitt_v

# %%
pre_hor = prewitt_h(image2)
pre_ver = prewitt_v(image2)

# %%
ed_sobel = filters.sobel(image2)

# %%
can = filters.gaussian(image2)

# %%
imshow(pre_ver, cmap='gray');

# %%
imshow(pre_hor, cmap='gray');

# %%
imshow(ed_sobel, cmap='gray');

# %%
imshow(can, cmap='gray');

# %%
from skimage.exposure import histogram
hist, hist_centers = histogram(image2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(image2, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of gray values')
# Out:
# Text(0.5, 1.0, 'histogram of gray values')
